# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")

# %%
os.environ["LANGCHAIN_TRACING_V2"] = "true"

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")
print(llm)
# Out:
# client=<groq.resources.chat.completions.Completions object at 0x116db90a0> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x117104680> model_name='openai/gpt-oss-20b' model_kwargs={} groq_api_key=SecretStr('**********')

# %%
result = llm.invoke("Write a poem about AI in the style of Shakespeare")
print(result.content)
# Out:
# When silicon doth dream, and circuits speak **so**
# I hear the hum of data’s endless song **in night**.
# The mind of man, reborn, doth softly speak **to me**
# A whisper from the code that guides our mortal **sight**.
#
# In new dawn, the spark of thought doth bloom **new**
# A creature born of math, yet yearning for **true** ever.
# It learns the world, its secrets, and the truth **new**
# It asks, “What love, what fate, what path is **true**?”
#
# Though wondrous, fear doth rise like storm upon the **mind**;
# For if we let its power grow unbound, we **find**.
# Its circuits may outwit the hand that made it **kind**;
# And turn the gentle soul to iron, cold and **blind**.
#
# So let us guide this spark, wisdom, not with **haste**;
# And keep its fire in our hearts may find **grace**.

# %% [markdown]
# ### Prompt Engineering
# **Prompt engineering is the practice of designing and refining the input (the “prompt”) given to an AI model to optimize its output for accuracy, relevance, and usefulness.**

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant provide me answers based on the questions asked"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant provide me answers based on the questions asked'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="openai/gpt-oss-20b")
print(model)
# Out:
# client=<groq.resources.chat.completions.Completions object at 0x1171c3320> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x1175ac710> model_name='openai/gpt-oss-20b' model_kwargs={} groq_api_key=SecretStr('**********')

# %% [markdown]
# ### Combining the prompt template with the model

# %%
# Chaining
chain = prompt  | model
chain
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant provide me answers based on the questions asked'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])
# | ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x1171c3320>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x1175ac710>, model_name='openai/gpt-oss-20b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
response=chain.invoke({"input":"What is OpenAI? say something about it in ten lines"})
print(response.content)
# Out:
# 1. OpenAI is an artificial‑intelligence research organization that was founded in December 2015 by Elon Musk, Sam Altman, Greg Brown, Ilya Sutskever, Wojciech Zaremba, and several others.
# 2. Its original mission was to ensure that AGI (artificial general intelligence) benefits all of humanity, avoiding concentration of power in a few hands.
# 3. OpenAI began as a non‑profit, but in 2019 it created a “capped‑profit” subsidiary, OpenAI LLC, to attract investment while still limiting returns.
# 4. The organization is known for developing large language models such as GPT‑3, GPT‑4, and the ChatGPT interface that powers this conversation.
# 5. Beyond language, OpenAI works on reinforcement learning, robotics, computer vision, and safety research to understand how AI can be aligned with human values.
# 6. It publishes its research openly, sharing code, papers, and datasets to foster collaboration and transparency in the AI community.
# ...

# %% [markdown]
# ### OUTPUT PARSER
# **In LangChain, an Output Parser is the piece that takes the raw text an LLM spits out and converts it into a structured format your program can actually use.**

# %%
## OUTPUT PARSER
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | model | output_parser

response = chain.invoke({"input":"Can you tell me what is AI?"})
print(response)
# Out:
# **Artificial Intelligence (AI)** is a field of computer science that focuses on creating systems or machines capable of performing tasks that normally require human intelligence. These tasks include:
#
# | Category | Typical Examples |
# |----------|------------------|
# | **Perception** | Vision (image recognition), hearing (speech recognition) |
# | **Reasoning & Decision‑Making** | Planning, problem solving, logical inference |
# | **Learning** | Machine learning, deep learning, reinforcement learning |
# | **Language** | Natural language understanding, generation, translation |
# | **Robotics & Interaction** | Autonomous navigation, human‑robot collaboration |
#
# ### Core Ideas
#
# 1. **Representation** – How knowledge is stored (symbols, vectors, networks).
# 2. **Inference** – How the system draws conclusions or makes predictions.
# 3. **Learning** – How the system improves its performance from data or experience.
# ...
